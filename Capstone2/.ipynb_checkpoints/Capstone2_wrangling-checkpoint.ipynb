# %%
# Importing packages

import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
# Function to open the csv files and merge them by the columns 'Entity' and 'Year'

def merge_csv(folder_path):
    all_dataframes = []

    for file_name in os.listdir(folder_path):
        if file_name.endswith('.csv'):
            file_path = os.path.join(folder_path, file_name)
            df = pd.read_csv(file_path)
            all_dataframes.append(df)

    merged_df = pd.concat(all_dataframes, ignore_index=True)
    merged_df = merged_df.groupby(['Entity', 'Year']).sum().reset_index()

    return merged_df

# %%
df = merge_csv('data/')

# saving the csv

df.to_csv('merged_total_dataset.csv', index=False)
# Out:
# /var/folders/tn/_cldsrsx169d6c6_fzk5x91h0000gn/T/ipykernel_19980/1770646144.py:13: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   merged_df = merged_df.groupby(['Entity', 'Year']).sum().reset_index()

# %%
# Finding the label for USA

print(np.unique(df['Entity']))
# Out:
# ['Afghanistan' 'Africa' 'Africa (BP)' 'Africa (Ember)' 'Albania' 'Algeria'
#  'American Samoa' 'Angola' 'Antigua and Barbuda' 'Argentina' 'Armenia'
#  'Aruba' 'Asia' 'Asia (Ember)' 'Asia Pacific' 'Asia Pacific (BP)'
#  'Australia' 'Austria' 'Azerbaijan' 'Bahamas' 'Bahrain' 'Bangladesh'
#  'Barbados' 'Belarus' 'Belgium' 'Belize' 'Benin' 'Bermuda' 'Bhutan'
#  'Bolivia' 'Bosnia and Herzegovina' 'Botswana' 'Brazil'
#  'British Virgin Islands' 'Brunei' 'Bulgaria' 'Burkina Faso' 'Burundi'
#  'CIS' 'CIS (BP)' 'Cambodia' 'Cameroon' 'Canada' 'Cape Verde'
#  'Cayman Islands' 'Central African Republic' 'Central America (BP)' 'Chad'
#  'Chile' 'China' 'Colombia' 'Comoros' 'Congo' 'Cook Islands' 'Costa Rica'
#  "Cote d'Ivoire" 'Croatia' 'Cuba' 'Cyprus' 'Czechia'
#  'Democratic Republic of Congo' 'Denmark' 'Djibouti' 'Dominica'
#  'Dominican Republic' 'Eastern Africa (BP)' 'Ecuador' 'Egypt'
#  'El Salvador' 'Equatorial Guinea' 'Eritrea' 'Estonia' 'Eswatini'
#  'Ethiopia' 'Europe' 'Europe (BP)' 'Europe (Ember)' 'European Union (27)'
#  'European Union (27) (Ember)' 'Faeroe Islands' 'Falkland Islands' 'Fiji'
#  'Finland' 'France' 'French Guiana' 'French Polynesia' 'G20 (Ember)'
#  'G7 (Ember)' 'Gabon' 'Gambia' 'Georgia' 'Germany' 'Ghana' 'Gibraltar'
#  'Greece' 'Greenland' 'Grenada' 'Guadeloupe' 'Guam' 'Guatemala' 'Guinea'
#  'Guinea-Bissau' 'Guyana' 'Haiti' 'High-income countries' 'Honduras'
#  'Hong Kong' 'Hungary' 'Iceland' 'India' 'Indonesia' 'Iran' 'Iraq'
#  'Ireland' 'Israel' 'Italy' 'Jamaica' 'Japan' 'Jordan' 'Kazakhstan'
#  'Kenya' 'Kiribati' 'Kosovo' 'Kuwait' 'Kyrgyzstan' 'Laos'
#  'Latin America and Caribbean (Ember)' 'Latvia' 'Lebanon' 'Lesotho'
#  'Liberia' 'Libya' 'Lithuania' 'Low-income countries'
#  'Lower-middle-income countries' 'Luxembourg' 'Macao' 'Madagascar'
#  'Malawi' 'Malaysia' 'Maldives' 'Mali' 'Malta' 'Martinique' 'Mauritania'
#  'Mauritius' 'Mexico' 'Middle Africa (BP)' 'Middle East (BP)' 'Moldova'
#  'Mongolia' 'Montenegro' 'Montserrat' 'Morocco' 'Mozambique' 'Myanmar'
#  'Namibia' 'Nauru' 'Nepal' 'Netherlands' 'New Caledonia' 'New Zealand'
#  'Nicaragua' 'Niger' 'Nigeria' 'Niue' 'Non-OECD (BP)' 'North America'
#  'North America (BP)' 'North America (Ember)' 'North Korea'
#  'North Macedonia' 'Norway' 'OECD (BP)' 'OECD (Ember)' 'Oceania'
#  'Oceania (Ember)' 'Oman' 'Other Europe' 'Other South & Central America'
#  'Pakistan' 'Palestine' 'Panama' 'Papua New Guinea' 'Paraguay' 'Peru'
#  'Philippines' 'Poland' 'Portugal' 'Puerto Rico' 'Qatar' 'Reunion'
#  'Romania' 'Russia' 'Rwanda' 'Saint Helena' 'Saint Kitts and Nevis'
#  'Saint Lucia' 'Saint Pierre and Miquelon'
#  'Saint Vincent and the Grenadines' 'Samoa' 'Sao Tome and Principe'
#  'Saudi Arabia' 'Senegal' 'Serbia' 'Seychelles' 'Sierra Leone' 'Singapore'
#  'Slovakia' 'Slovenia' 'Solomon Islands' 'Somalia'
#  'South & Central America' 'South Africa' 'South America' 'South Korea'
#  'South Sudan' 'South and Central America (BP)' 'Spain' 'Sri Lanka'
#  'Sudan' 'Suriname' 'Sweden' 'Switzerland' 'Syria' 'Taiwan' 'Tajikistan'
#  'Tanzania' 'Thailand' 'Timor' 'Togo' 'Tonga' 'Trinidad and Tobago'
#  'Tunisia' 'Turkey' 'Turkmenistan' 'Turks and Caicos Islands' 'USSR'
#  'Uganda' 'Ukraine' 'United Arab Emirates' 'United Kingdom'
#  'United States' 'United States Virgin Islands'
#  'Upper-middle-income countries' 'Uruguay' 'Uzbekistan' 'Vanuatu'
#  'Venezuela' 'Vietnam' 'Western Africa (BP)' 'Western Sahara' 'World'
#  'Yemen' 'Zambia' 'Zimbabwe']

# %%
# Filtering the data for USA only
usa = df[df['Entity'] == 'United States']

# %%
# saving the final csv

usa.to_csv('merged_usa_dataset.csv', index=False)

# %%
# analysing the dataframe

usa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57 entries, 8461 to 8517
# Data columns (total 22 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Entity                                      57 non-null     object
#  1   Year                                        57 non-null     int64
#  2   Geo Biomass Other - TWh                     57 non-null     float64
#  3   Solar Generation - TWh                      57 non-null     float64
#  4   Wind Generation - TWh                       57 non-null     float64
#  5   Hydro Generation - TWh                      57 non-null     float64
#  6   Electricity from solar (TWh)                57 non-null     float64
#  7   Solar Capacity                              57 non-null     float64
#  8   Geothermal Capacity                         57 non-null     float64
#  9   Solar (% electricity)                       57 non-null     float64
#  10  Wind (% electricity)                        57 non-null     float64
#  11  Hydro (% equivalent primary energy)         57 non-null     float64
#  12  Solar (% equivalent primary energy)         57 non-null     float64
#  13  Renewables (% equivalent primary energy)    57 non-null     float64
#  14  Wind (% equivalent primary energy)          57 non-null     float64
#  15  Electricity from hydro (TWh)                57 non-null     float64
#  16  Biofuels Production - TWh - Total           57 non-null     float64
#  17  Electricity from wind (TWh)                 57 non-null     float64
#  18  Other renewables including bioenergy (TWh)  57 non-null     float64
#  19  Wind Capacity                               57 non-null     float64
#  20  Hydro (% electricity)                       57 non-null     float64
#  21  Renewables (% electricity)                  57 non-null     float64
# dtypes: float64(20), int64(1), object(1)
# memory usage: 10.2+ KB

# %%
usa.describe().T
# Out:
#                                             count         mean          std  \
# Year                                         57.0  1993.000000    16.598193
# Geo Biomass Other - TWh                      57.0    51.640315    24.831284
# Solar Generation - TWh                       57.0    13.143548    34.702751
# Wind Generation - TWh                        57.0    52.347070    98.781362
# Hydro Generation - TWh                       57.0   274.981598    33.478110
# Electricity from solar (TWh)                 57.0    25.374476    68.942213
# Solar Capacity                               57.0     7.415070    19.288595
# Geothermal Capacity                          57.0   995.899298  1231.805291
# Solar (% electricity)                        57.0     0.308808     0.836247
# Wind (% electricity)                         57.0     1.267605     2.375313
# Hydro (% equivalent primary energy)          57.0     3.557790     0.696467
# Solar (% equivalent primary energy)          57.0     0.135164     0.354995
# Renewables (% equivalent primary energy)     57.0     5.303081     1.705532
# Wind (% equivalent primary energy)           57.0     0.545342     1.016217
# Electricity from hydro (TWh)                 57.0   547.594989    67.588075
# Biofuels Production - TWh - Total            57.0   103.151536   151.322025
# Electricity from wind (TWh)                  57.0   103.603974   195.393345
# Other renewables including bioenergy (TWh)   57.0    51.265390    24.452388
# Wind Capacity                                57.0    19.024343    34.748126
# Hydro (% electricity)                        57.0     4.866521     3.775441
# Renewables (% electricity)                   57.0     7.606756     6.241404
#
#                                                     min          25%  \
# Year                                        1965.000000  1979.000000
# Geo Biomass Other - TWh                       13.332232    25.756037
# Solar Generation - TWh                         0.000000     0.000000
# Wind Generation - TWh                          0.000000     0.000000
# Hydro Generation - TWh                       198.974090   256.028530
# Electricity from solar (TWh)                   0.000000     0.000000
# Solar Capacity                                 0.000000     0.000000
# Geothermal Capacity                            0.000000     0.000000
# Solar (% electricity)                          0.000000     0.000000
# Wind (% electricity)                           0.000000     0.000000
# Hydro (% equivalent primary energy)            2.383536     2.967953
# Solar (% equivalent primary energy)            0.000000     0.000000
# Renewables (% equivalent primary energy)       3.421371     4.327570
# Wind (% equivalent primary energy)             0.000000     0.000000
# Electricity from hydro (TWh)                 397.948180   509.400000
# Biofuels Production - TWh - Total              0.000000     0.000000
# Electricity from wind (TWh)                    0.000000     0.000000
# Other renewables including bioenergy (TWh)    13.332232    25.756037
# Wind Capacity                                  0.000000     0.000000
# Hydro (% electricity)                          0.000000     0.000000
# Renewables (% electricity)                     0.000000     0.000000
#
#                                                     50%          75%  \
# Year                                        1993.000000  2007.000000
# Geo Biomass Other - TWh                       64.815414    73.159860
# Solar Generation - TWh                         0.478253     1.095411
# Wind Generation - TWh                          3.036189    34.797905
# Hydro Generation - TWh                       274.030030   289.822450
# Electricity from solar (TWh)                   0.956506     1.220000
# Solar Capacity                                 0.000000     0.974000
# Geothermal Capacity                            0.000000  2382.000000
# Solar (% electricity)                          0.012888     0.014777
# Wind (% electricity)                           0.089173     0.831609
# Hydro (% equivalent primary energy)            3.602766     4.084431
# Solar (% equivalent primary energy)            0.005903     0.011445
# Renewables (% equivalent primary energy)       4.614475     5.334361
# Wind (% equivalent primary energy)             0.038384     0.363568
# Electricity from hydro (TWh)                 544.508000   579.644900
# Biofuels Production - TWh - Total             22.044724   162.899440
# Electricity from wind (TWh)                    6.072378    68.900000
# Other renewables including bioenergy (TWh)    64.640000    72.240005
# Wind Capacity                                  0.000000    16.515000
# Hydro (% electricity)                          6.506543     7.653214
# Renewables (% electricity)                     9.291262    11.360623
#
#                                                     max
# Year                                        2021.000000
# Geo Biomass Other - TWh                       84.070230
# Solar Generation - TWh                       165.356570
# Wind Generation - TWh                        383.603270
# Hydro Generation - TWh                       355.973100
# Electricity from solar (TWh)                 328.840000
# Solar Capacity                                93.713016
# Geothermal Capacity                         3170.960000
# Solar (% electricity)                          3.959809
# Wind (% electricity)                           9.108380
# Hydro (% equivalent primary energy)            5.202278
# Solar (% equivalent primary energy)            1.675419
# Renewables (% equivalent primary energy)      10.655991
# Wind (% equivalent primary energy)             3.886730
# Electricity from hydro (TWh)                 711.946200
# Biofuels Production - TWh - Total            424.440060
# Electricity from wind (TWh)                  756.400000
# Other renewables including bioenergy (TWh)    83.070000
# Wind Capacity                                132.737600
# Hydro (% electricity)                         11.097251
# Renewables (% electricity)                    20.749863

# %%
# checking for null values

missing = pd.concat([usa.isnull().sum(), 100 * usa.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count', ascending=False)
# Out:
#                                             count    %
# Entity                                          0  0.0
# Year                                            0  0.0
# Hydro (% electricity)                           0  0.0
# Wind Capacity                                   0  0.0
# Other renewables including bioenergy (TWh)      0  0.0
# Electricity from wind (TWh)                     0  0.0
# Biofuels Production - TWh - Total               0  0.0
# Electricity from hydro (TWh)                    0  0.0
# Wind (% equivalent primary energy)              0  0.0
# Renewables (% equivalent primary energy)        0  0.0
# Solar (% equivalent primary energy)             0  0.0
# Hydro (% equivalent primary energy)             0  0.0
# Wind (% electricity)                            0  0.0
# Solar (% electricity)                           0  0.0
# Geothermal Capacity                             0  0.0
# Solar Capacity                                  0  0.0
# Electricity from solar (TWh)                    0  0.0
# Hydro Generation - TWh                          0  0.0
# Wind Generation - TWh                           0  0.0
# Solar Generation - TWh                          0  0.0
# Geo Biomass Other - TWh                         0  0.0
# Renewables (% electricity)                      0  0.0

# %%
# Ploting histograms of the columns 

usa.hist(figsize=(15, 10), edgecolor='black')
plt.subplots_adjust(hspace=0.5);

# %%
# Out:
# <Axes: >
